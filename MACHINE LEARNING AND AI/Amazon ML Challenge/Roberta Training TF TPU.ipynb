# %% [markdown]
# ## Importing

# %%
# !pip install transformers -q
# Out:
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
import os
import csv
import time
import warnings

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
import transformers
import tensorflow_hub as hub

from tqdm.notebook import tqdm
from sklearn.preprocessing import LabelEncoder

warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Config

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print(f'Running on TPU {tpu.master()}')
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy()

AUTO = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync
print(f'REPLICAS: {REPLICAS}')
# Out:
# Running on TPU grpc://10.0.0.2:8470
# REPLICAS: 8

# %%
BATCH_SIZE = 512
MAX_LEN = 250

# %% [markdown]
# ## Loading data

# %%
train = pd.read_csv('../input/amazon/new_train.csv', 
                    usecols=['TITLE', 'BULLET_POINTS', 'label3', 'split3'])
train.fillna('nan', inplace=True)

num_classes = train['label3'].nunique()

# %% [markdown]
# ## Prepraing dataset

# %%
le = LabelEncoder()
train['label3'] = le.fit_transform(train['label3'])

train_df, valid_df = train[train['split3'] == 'train'], train[train['split3'] == 'valid']
train_df['text'] = train_df['TITLE'] + " " + train_df['BULLET_POINTS']
valid_df['text'] = valid_df['TITLE'] + " " + valid_df['BULLET_POINTS']

train_text = train_df['text'].values
valid_text = valid_df['text'].values

train_label = train_df['label3'].values
valid_label = valid_df['label3'].values

# %%
tokenizer = transformers.RobertaTokenizerFast.from_pretrained('roberta-base')
# Out:
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %% [markdown]
# ## Creating model

# %%
def create_model():
    bert = transformers.TFRobertaModel.from_pretrained('roberta-base', 
                                                    output_attentions=False, 
                                                    output_hidden_states=False)
    inputs = tf.keras.layers.Input((None,), dtype=tf.int32)
    mask = tf.keras.layers.Input((None,), dtype=tf.int32)
    bert_outputs = bert(inputs, attention_mask=mask)[1]
    preds = tf.keras.layers.Dense(num_classes, activation='softmax')(bert_outputs)
    return tf.keras.Model([inputs, mask], preds)

# %% [markdown]
# ## Training Function

# %%
print('creating model')
with strategy.scope():
    model = create_model()
    optimizer = tf.keras.optimizers.Adam(learning_rate=3e-5, epsilon=1e-08)
    loss_fun = tf.keras.losses.SparseCategoricalCrossentropy()
    model.compile(optimizer=optimizer, loss=loss_fun, metrics=['acc'])
# Out:
# creating model
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/657M [00:00<?, ?B/s]
# Some layers from the model checkpoint at roberta-base were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.

# %%
def train_chunk(start, end):
  
    valid_idx = np.random.randint(0, len(valid_text)-1, size=25000)

    valid_text_chunk = list(valid_text[valid_idx])
    train_text_chunk = list(train_text[start:end])

    train_label_chunk = train_label[start:end]
    valid_label_chunk = valid_label[valid_idx]

    start = time.time()
    print('Tokenizing data')
    train_data = tokenizer(train_text_chunk, padding=True, truncation=True, max_length=MAX_LEN)
    valid_data = tokenizer(valid_text_chunk, padding=True, truncation=True, max_length=MAX_LEN)
    print('Tokenization complete, time taken = ', time.time() - start)

    start = time.time()
    print('creating dataset')
    train_dataset = tf.data.Dataset.from_tensor_slices(((train_data['input_ids'], 
                                                       train_data['attention_mask']), 
                                                       train_label_chunk)).batch(BATCH_SIZE)

    valid_dataset = tf.data.Dataset.from_tensor_slices(((valid_data['input_ids'], 
                                                       valid_data['attention_mask']), 
                                                       valid_label_chunk)).batch(BATCH_SIZE)
    print('dataset created, time taken = ', time.time() - start)

    print('TRAINING')
    model.fit(train_dataset,
            epochs=2,
            validation_data=valid_dataset)

    print('Saving weights')
    model.save_weights('./tpu_model_roberta.h5')

# %% [markdown]
# ## Training the model

# %%
len(train_df)
# Out:
# 2123582

# %%
start = 0
for i in range(100000, 2000000, 100000):
    train_chunk(start, i)
    start = i
# Out:
# Tokenizing data
# Tokenization complete, time taken =  27.52086901664734
# creating dataset
# dataset created, time taken =  211.2838213443756
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 236s 808ms/step - loss: 6.3699 - acc: 0.1678 - val_loss: 4.1654 - val_acc: 0.4024
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 3.9216 - acc: 0.4412 - val_loss: 3.1883 - val_acc: 0.5230
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  26.5440616607666
# creating dataset
# dataset created, time taken =  211.30549120903015
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 486ms/step - loss: 3.0045 - acc: 0.5419 - val_loss: 2.6617 - val_acc: 0.5762
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 2.5259 - acc: 0.5930 - val_loss: 2.3456 - val_acc: 0.6099
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  26.593314170837402
# creating dataset
# dataset created, time taken =  210.4616186618805
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 486ms/step - loss: 2.3189 - acc: 0.6118 - val_loss: 2.1159 - val_acc: 0.6343
# Epoch 2/2
# 196/196 [==============================] - 95s 484ms/step - loss: 2.0338 - acc: 0.6446 - val_loss: 1.9451 - val_acc: 0.6548
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  26.633644342422485
# creating dataset
# dataset created, time taken =  210.57513117790222
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 486ms/step - loss: 1.9657 - acc: 0.6478 - val_loss: 1.8182 - val_acc: 0.6627
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 1.7543 - acc: 0.6741 - val_loss: 1.7180 - val_acc: 0.6736
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  25.61212992668152
# creating dataset
# dataset created, time taken =  211.98081827163696
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 486ms/step - loss: 1.7266 - acc: 0.6710 - val_loss: 1.6367 - val_acc: 0.6832
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 1.5511 - acc: 0.6959 - val_loss: 1.5665 - val_acc: 0.6906
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  25.70943808555603
# creating dataset
# dataset created, time taken =  212.5522530078888
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 487ms/step - loss: 1.5527 - acc: 0.6901 - val_loss: 1.4762 - val_acc: 0.6985
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 1.4023 - acc: 0.7132 - val_loss: 1.4329 - val_acc: 0.7046
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  25.694971561431885
# creating dataset
# dataset created, time taken =  211.5424301624298
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 486ms/step - loss: 1.4401 - acc: 0.7023 - val_loss: 1.3701 - val_acc: 0.7133
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 1.2991 - acc: 0.7236 - val_loss: 1.3429 - val_acc: 0.7174
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  26.41671061515808
# creating dataset
# dataset created, time taken =  211.46920800209045
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 487ms/step - loss: 1.3630 - acc: 0.7121 - val_loss: 1.2876 - val_acc: 0.7230
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 1.2308 - acc: 0.7348 - val_loss: 1.2620 - val_acc: 0.7283
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  25.450599908828735
# creating dataset
# dataset created, time taken =  210.52500128746033
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 486ms/step - loss: 1.2982 - acc: 0.7183 - val_loss: 1.2091 - val_acc: 0.7322
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 1.1682 - acc: 0.7415 - val_loss: 1.1968 - val_acc: 0.7343
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  25.334398984909058
# creating dataset
# dataset created, time taken =  212.10495114326477
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 486ms/step - loss: 1.2316 - acc: 0.7282 - val_loss: 1.1848 - val_acc: 0.7337
# Epoch 2/2
# 196/196 [==============================] - 96s 491ms/step - loss: 1.1091 - acc: 0.7488 - val_loss: 1.1747 - val_acc: 0.7363
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  24.96537685394287
# creating dataset
# dataset created, time taken =  211.07140374183655
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 486ms/step - loss: 1.2090 - acc: 0.7299 - val_loss: 1.1192 - val_acc: 0.7456
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 1.0860 - acc: 0.7521 - val_loss: 1.1100 - val_acc: 0.7481
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  26.143027305603027
# creating dataset
# dataset created, time taken =  210.79647970199585
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 486ms/step - loss: 1.1575 - acc: 0.7372 - val_loss: 1.0853 - val_acc: 0.7505
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 1.0410 - acc: 0.7583 - val_loss: 1.0801 - val_acc: 0.7508
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  26.264254331588745
# creating dataset
# dataset created, time taken =  212.8646204471588
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 486ms/step - loss: 1.1213 - acc: 0.7443 - val_loss: 1.0881 - val_acc: 0.7489
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 1.0000 - acc: 0.7674 - val_loss: 1.0898 - val_acc: 0.7481
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  25.461941957473755
# creating dataset
# dataset created, time taken =  211.249338388443
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 486ms/step - loss: 1.1134 - acc: 0.7423 - val_loss: 1.0572 - val_acc: 0.7544
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 0.9897 - acc: 0.7664 - val_loss: 1.0584 - val_acc: 0.7532
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  25.775762796401978
# creating dataset
# dataset created, time taken =  211.2229609489441
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 486ms/step - loss: 1.0880 - acc: 0.7465 - val_loss: 1.0475 - val_acc: 0.7553
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 0.9669 - acc: 0.7700 - val_loss: 1.0511 - val_acc: 0.7560
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  26.31453251838684
# creating dataset
# dataset created, time taken =  211.18543028831482
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 487ms/step - loss: 1.0708 - acc: 0.7504 - val_loss: 1.0271 - val_acc: 0.7582
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 0.9465 - acc: 0.7744 - val_loss: 1.0268 - val_acc: 0.7577
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  26.24730086326599
# creating dataset
# dataset created, time taken =  211.4151430130005
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 487ms/step - loss: 1.0519 - acc: 0.7533 - val_loss: 0.9931 - val_acc: 0.7666
# Epoch 2/2
# 196/196 [==============================] - 96s 489ms/step - loss: 0.9305 - acc: 0.7771 - val_loss: 0.9966 - val_acc: 0.7675
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  26.00122094154358
# creating dataset
# dataset created, time taken =  211.94779682159424
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 487ms/step - loss: 1.0341 - acc: 0.7540 - val_loss: 0.9903 - val_acc: 0.7627
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 0.9106 - acc: 0.7798 - val_loss: 0.9942 - val_acc: 0.7634
# Saving weights
# Tokenizing data
# Tokenization complete, time taken =  26.803122520446777
# creating dataset
# dataset created, time taken =  211.9038302898407
# TRAINING
# Epoch 1/2
# 196/196 [==============================] - 95s 486ms/step - loss: 1.0224 - acc: 0.7573 - val_loss: 0.9823 - val_acc: 0.7674
# Epoch 2/2
# 196/196 [==============================] - 95s 485ms/step - loss: 0.8998 - acc: 0.7811 - val_loss: 0.9884 - val_acc: 0.7652
# Saving weights

# %% [markdown]
# ## Predicting on test set

# %%
model.load_weights('./tpu_model_roberta.h5')
test = pd.read_csv('../input/amazontest/test.csv', escapechar='\\', quoting=csv.QUOTE_NONE)
test.head()
# Out:
#    PRODUCT_ID                                              TITLE  \
# 0           1  Command 3M Small Kitchen Hooks, White, Decorat...
# 1           2  O'Neal Jump Hardware JAG Unisex-Adult Glove (B...
# 2           3  NFL Detroit Lions Portable Party Fridge, 15.8 ...
# 3           4  Panasonic Single Line KX-TS880MX Corded Phone ...
# 4           5  Zero Baby Girl's 100% Cotton Innerwear Bloomer...
#
#                                          DESCRIPTION  \
# 0                                    Sale Unit: PACK
# 1  Synthetic leather palm with double-layer thumb...
# 2  Boelter Brands lets you celebrate your favorit...
# 3  Features: 50 Station Phonebook Corded Phone Al...
# 4  Zero Baby Girl Panties Set. 100% Cotton, Breat...
#
#                                        BULLET_POINTS           BRAND
# 0  [INCLUDES - 9 hooks and 12 small indoor strips...         Command
# 1  [Silicone printing for a better grip. Long las...          O'Neal
# 2  [Runs on 12 Volt DC Power or 110 Volt AC Power...  Boelter Brands
# 3  Panasonic Landline Phones doesn't come with a ...       Panasonic
# 4  [Zero Baby Girl Panties, Pack of 6, 100% Cotto...            Zero

# %%
test.fillna('nan', inplace=True)
len(test)
# Out:
# 110775

# %%
test_text = test['TITLE'] + " " + test['BULLET_POINTS']

# %%
test_data = tokenizer(list(test_text.values), padding=True, truncation=True, max_length=MAX_LEN)

# %%
test_dataset = tf.data.Dataset.from_tensor_slices(((test_data['input_ids'], 
                                                    test_data['attention_mask']), 
                                                   test['PRODUCT_ID'].values)).batch(BATCH_SIZE)

# %%
product_ids = []
sample_preds = []
for i in tqdm(test_dataset):
    product_ids += list(i[1].numpy())
    sample_preds += list(np.argmax(model.predict(i[0]), axis=1))
# Out:
#   0%|          | 0/217 [00:00<?, ?it/s]

# %%
train = pd.read_csv('../input/amazon/new_train.csv', 
                    usecols=['label3'])
train.fillna('nan', inplace=True)

# %%
le = LabelEncoder()
transformed = le.fit_transform(train['label3'])

# %%
inverse = {}

for i, j in zip(transformed, train['label3']):
    inverse[i] = j

# %%
# Temp sub
sub = pd.DataFrame()
sub['PRODUCT_ID'] = product_ids
sub['BROWSE_NODE_ID'] = sample_preds
sub['BROWSE_NODE_ID'] = sub['BROWSE_NODE_ID'].map(inverse)

# %%
sub.to_csv('./RobertaSubmission.csv', index=False)

# %%
sub.head()
# Out:
#    PRODUCT_ID  BROWSE_NODE_ID
# 0           1            1140
# 1           2            3329
# 2           3               0
# 3           4             125
# 4           5            8915
