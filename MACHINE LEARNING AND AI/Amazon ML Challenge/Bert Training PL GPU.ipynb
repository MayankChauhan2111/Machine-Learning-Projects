# %%
# !nvidia-smi
# Out:
# Sun Aug  1 03:10:49 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Imports

# %%
# !pip install cloud-tpu-client==0.10 https://storage.googleapis.com/tpu-pytorch/wheels/torch_xla-1.9-cp37-cp37m-linux_x86_64.whl

# %%
# !pip install wandb -q --upgrade
# !pip install texthero -q --upgrade
# !pip install datasets -q --upgrade
# !pip install transformers -q --upgrade
# !pip install torch_snippets -q --upgrade
# !pip install pytorch-lightning -q --upgrade

# %%
import os
import csv
import glob
import wandb
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import torch
import transformers
import tensorflow as tf
import torchmetrics as tm
import pytorch_lightning as pl

from torch.utils.data import Dataset, DataLoader

from texthero import clean
from torch_snippets import *
from tqdm.notebook import tqdm

from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
# Out:
# 2021-08-01 02:54:19.212 | WARNING  | torch_snippets:<module>:9 - torch is not found. Skipping relevant imports from submodule `torch_loader`
# Exception: cannot import name 'makedir' from 'torch_snippets.loader' (/usr/local/lib/python3.7/dist-packages/torch_snippets/loader.py)
# 2021-08-01 02:54:19.216 | WARNING  | torch_snippets:<module>:14 - sklearn is not found. Skipping relevant imports from submodule `sklegos`
# Exception: No module named 'sklego'

# %% [markdown]
# ## Config

# %%
class Config:
  SEED = 1234
  DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

  dataset = '/content/drive/MyDrive/AmazonML/input/dataset/train.csv'
  debug = False

  max_len = 500

  model = 'prajjwal1/bert-small'
  epochs = 5
  batch_size = 64

  threshold = 200

config = Config()

# %% [markdown]
# ## Loading the data

# %%
df = pd.read_csv(config.dataset, escapechar='\\', quoting=csv.QUOTE_NONE)

# %%
df.fillna('nan', inplace=True)
df.head(2)
# Out:
#                                                TITLE  ... BROWSE_NODE_ID
# 0         Pete The Cat Bedtime Blues Doll, 14.5 Inch  ...              0
# 1  The New Yorker NYHM014 Refrigerator Magnet, 2 ...  ...              1
#
# [2 rows x 5 columns]

# %% [markdown]
# ## EDA

# %%
temp = df.BROWSE_NODE_ID.value_counts()
value_counts = {}
for i, j in zip(temp.index, temp):
  value_counts[i] = j

# %%
df['BROWSE_NODE_ID'].nunique()
# Out:
# 9919

# %%
values = []
ranges = []
for i in range(1,100,5):
    values.append(np.sum(df.BROWSE_NODE_ID.value_counts() > i))
    ranges.append(i)
    
sns.lineplot(x=ranges, y=values)

# %%
df['Threshold'] = df['BROWSE_NODE_ID'].map(lambda x: 1 if value_counts[x] >= 80 else 0)
np.sum(df['Threshold']) / len(df) # dataset percentage coverage

# %%
df['label'] = df['BROWSE_NODE_ID'] * df['Threshold']
df['label'].nunique() # How many classes we have in the threshold
# Out:
# 1683

# %%
# Let's train only on these thresholds
df = df[df['Threshold'] == 1]

# %%
# Brands
df['BRAND'].nunique() # let's leave it aside for now
# Out:
# 225958

# %% [markdown]
# ## Preprocessing the dataset

# %% [markdown]
# ### Sampling the dataset

# %%
new_df = df.groupby('BROWSE_NODE_ID').sample(config.threshold, random_state=1234).reset_index(drop=True) # Limiting each class occurance
new_df = new_df.sample(frac=1, random_state=1234).reset_index(drop=True) # Shuffling the dataset

# label encoding
le = LabelEncoder()
le.fit(new_df['BROWSE_NODE_ID'])
transformed = le.transform(new_df['BROWSE_NODE_ID'])

inverse = {}
for i, j in zip(transformed, new_df['BROWSE_NODE_ID'].values):
  inverse[i] = j

new_df['label'] = transformed
num_classes = new_df['label'].nunique()

# %%
new_df.head()
# Out:
#                                                TITLE  ... label
# 0  Dios Combo of Car Rain Wind Door Visor Side Wi...  ...   746
# 1  Darice 9 X 12 Inches -2 mm Glitter Foam Sheet ...  ...  1123
# 2  Eatech USB LED Dim Decorative Ambience Atmosph...  ...  1478
# 3  Gusto Black Casual Rubber Clogs for Men's (6 U...  ...   675
# 4  DMC 1008F-S5200 Shiny Radiant Satin Floss, Sno...  ...   117
#
# [5 rows x 7 columns]

# %% [markdown]
# ### EDA on counts

# %%
# Looking the word counts

new_df['title_len'] = new_df['TITLE'].map(len)
new_df['des_len'] = new_df['DESCRIPTION'].map(len)
new_df['bp_len'] = new_df['BULLET_POINTS'].map(len)

# %%
sns.distplot(new_df['title_len'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.distplot(new_df['des_len'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.distplot(new_df['bp_len'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.distplot(new_df['title_len'] + new_df['bp_len'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# ### Cleaning the dataset

# %%
# %%time
# new_df['TITLE'] = clean(new_df['TITLE'])
# new_df['BULLET_POINTS'] = clean(new_df['BULLET_POINTS'])

# %% [markdown]
# ### Splitting the dataset

# %%
train_df, valid_df = train_test_split(new_df, stratify=new_df['label'], random_state=1234)

# %% [markdown]
# ### Observation:
#
#
# *   700 should be a reasonable length
# *   Now we will train a model with title + bullet_points

# %% [markdown]
# ## Creating the dataset

# %%
tokenizer = transformers.BertTokenizer.from_pretrained(config.model)

# %%
sample = tokenizer.encode_plus(train_df['TITLE'][0], train_df['BULLET_POINTS'][0])
tokenizer.decode(sample['input_ids'])
# Out:
# '[CLS] dios combo car rain wind door visor side window deflector sun shade microfiber cloth mahindra logan [SEP] vehicle compatibility mahindra logan door visors enables natural air circulation inside car preventing rain dirt external pollutants entering inside car provide elegant appearance enrich look car helps reduce heat build parked vehicles allowing windows partially opened easy install included 3m branded tape keeps rain let fresh air percent color fade resistance guarantee custom made fit door [SEP]'

# %%
class TrainDataset(Dataset):
  def __init__(self, df, tokenizer):
    self.titles = df['TITLE'].values
    self.bp     = df['BULLET_POINTS'].values
    self.tokenizer = tokenizer
    self.targets = df['label'].values

  def __len__(self):
    return len(self.titles)

  def __getitem__(self, idx):
    title = self.titles[idx]
    bp = self.bp[idx]
    target = self.targets[idx]

    text = str(title) + " " + str(bp)

    inputs = self.tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        max_length = config.max_len,
        truncation = True,
        padding = True
    )

    ids = inputs['input_ids']
    token_type_ids = inputs['token_type_ids']
    mask = inputs['attention_mask']

    padding_len = config.max_len - len(ids)
    ids =  ids + ([0] * padding_len)
    token_type_ids = token_type_ids + ([0] * padding_len)
    mask = mask + ([0] * padding_len)

    return {'ids':torch.tensor(ids, dtype=torch.long),
            'mask':torch.tensor(mask, dtype=torch.long),
            'ttids':torch.tensor(token_type_ids, dtype=torch.long),
            'targets':torch.tensor(target, dtype=torch.long)}

# %%
train_ds = TrainDataset(train_df, tokenizer)
valid_ds = TrainDataset(valid_df, tokenizer)

train_dl = DataLoader(train_ds,
                      batch_size=config.batch_size,
                      num_workers=4,
                      pin_memory=True)

valid_dl = DataLoader(valid_ds,
                      batch_size=config.batch_size,
                      num_workers=4,
                      pin_memory=True)

# %%
for i in train_dl:
  print(i['ids'].shape)
  break
# Out:
# torch.Size([64, 500])

# %% [markdown]
# ## Creating Model

# %%
class AmazonModel(pl.LightningModule):
  def __init__(self):
    super(AmazonModel, self).__init__()
    self.base_model = transformers.BertModel.from_pretrained(config.model)
    self.hidden = torch.nn.Linear(self.base_model.pooler.dense.out_features, 1024)
    self.classifier = torch.nn.Linear(1024, num_classes)
    self.loss = torch.nn.CrossEntropyLoss()
    self.acc = tm.Accuracy()
  
  def forward(self, ids, mask, ttids):
    out = self.base_model(ids, attention_mask=mask, token_type_ids=ttids)
    out = self.hidden(out.pooler_output)
    return self.classifier(out)

  def training_step(self, batch, batch_nb):
    ids, mask, ttids, targets = batch['ids'], batch['mask'], batch['ttids'], batch['targets']
    preds = self(ids, mask, ttids)
    loss = self.loss(preds, targets)
    acc = self.acc(preds, targets)
    self.log_dict({'train_loss': loss, 'train_acc': acc})
    return loss

  def validation_step(self, batch, batch_nb):
    ids, mask, ttids, targets = batch['ids'], batch['mask'], batch['ttids'], batch['targets']
    preds = self(ids, mask, ttids)
    loss = self.loss(preds, targets)
    acc = self.acc(preds, targets)
    self.log_dict({'valid_loss': loss, 'valid_acc': acc})
    return loss

  def configure_optimizers(self):
    optimizer = torch.optim.Adam(self.parameters(), lr=0.0001)
    return optimizer

# %% [markdown]
# ## Training

# %%
wandb_logger = pl.loggers.WandbLogger(project='Amazon',
                                      name='bert-small',
                                      log_model=True)

# %%
model = AmazonModel()
trainer = pl.Trainer(gpus=1,
                     max_epochs=config.epochs,
                     progress_bar_refresh_rate=5,
                     precision=16,
                     log_every_n_steps=10,
                     logger=wandb_logger)
# Out:
# Some weights of the model checkpoint at prajjwal1/bert-small were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Using native 16bit precision.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs

# %%
trainer.fit(model, train_dl, valid_dl)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: Currently logged in as: abhishek_prajapat (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.11.1<br/>
#                 Syncing run <strong style="color:#cdcd00">bert-small</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/abhishek_prajapat/Amazon" target="_blank">https://wandb.ai/abhishek_prajapat/Amazon</a><br/>
#                 Run page: <a href="https://wandb.ai/abhishek_prajapat/Amazon/runs/nh8od1ky" target="_blank">https://wandb.ai/abhishek_prajapat/Amazon/runs/nh8od1ky</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210801_013459-nh8od1ky</code><br/><br/>
#   | Name       | Type             | Params
# ------------------------------------------------
# 0 | base_model | BertModel        | 28.8 M
# 1 | hidden     | Linear           | 525 K
# 2 | classifier | Linear           | 1.7 M
# 3 | loss       | CrossEntropyLoss | 0
# 4 | acc        | Accuracy         | 0
# ------------------------------------------------
# 31.0 M    Trainable params
# 0         Non-trainable params
# 31.0 M    Total params
# 124.056   Total estimated model params size (MB)
# Validation sanity check: 0it [00:00, ?it/s]
# Training: -1it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]
# Validating: 0it [00:00, ?it/s]

# %%
wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 1844<br/>Program ended successfully.
# VBox(children=(Label(value=' 355.19MB of 355.19MB uploaded (0.17MB deduped)\r'), FloatProgress(value=1.0, max=…
# Find user logs for this run at: <code>/content/wandb/run-20210801_013459-nh8od1ky/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210801_013459-nh8od1ky/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>1.18823</td></tr><tr><td>train_acc</td><td>0.73438</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>trainer/global_step</td><td>19724</td></tr><tr><td>_runtime</td><td>4369</td></tr><tr><td>_timestamp</td><td>1627786069</td></tr><tr><td>_step</td><td>1976</td></tr><tr><td>valid_loss</td><td>1.65231</td></tr><tr><td>valid_acc</td><td>0.66592</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train_loss</td><td>█▅▄▃▃▂▂▂▂▃▂▂▂▂▂▁▁▂▂▁▂▁▂▂▁▂▂▁▂▁▁▂▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁▂▄▅▅▆▅▇▆▅▆▇▆▇▅█▇▇▇▇██▇▇▇▇▇█▇█▇▇▇██▇▇█▇▇</td></tr><tr><td>epoch</td><td>▁▁▁▁▁▁▁▁▃▃▃▃▃▃▃▃▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆████████</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>valid_loss</td><td>█▁▁▃▆</td></tr><tr><td>valid_acc</td><td>▁▆███</td></tr></table><br/>
# Synced 5 W&B file(s), 0 media file(s), 3 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">bert-small</strong>: <a href="https://wandb.ai/abhishek_prajapat/Amazon/runs/nh8od1ky" target="_blank">https://wandb.ai/abhishek_prajapat/Amazon/runs/nh8od1ky</a><br/>

# %% [markdown]
# ## Predicting on test set

# %%
class AmazonModel(pl.LightningModule):
  def __init__(self):
    super(AmazonModel, self).__init__()
    self.base_model = transformers.BertModel.from_pretrained(config.model)
    self.hidden = torch.nn.Linear(self.base_model.pooler.dense.out_features, 1024)
    self.classifier = torch.nn.Linear(1024, 1299)
    self.loss = torch.nn.CrossEntropyLoss()
    self.acc = tm.Accuracy()
  
  def forward(self, ids, mask, ttids):
    out = self.base_model(ids, attention_mask=mask, token_type_ids=ttids)
    out = self.hidden(out.pooler_output)
    return self.classifier(out)

  def training_step(self, batch, batch_nb):
    ids, mask, ttids, targets = batch['ids'], batch['mask'], batch['ttids'], batch['targets']
    preds = self(ids, mask, ttids)
    loss = self.loss(preds, targets)
    acc = self.acc(preds, targets)
    self.log_dict({'train_loss': loss, 'train_acc': acc})
    return loss

  def validation_step(self, batch, batch_nb):
    ids, mask, ttids, targets = batch['ids'], batch['mask'], batch['ttids'], batch['targets']
    preds = self(ids, mask, ttids)
    loss = self.loss(preds, targets)
    acc = self.acc(preds, targets)
    self.log_dict({'valid_loss': loss, 'valid_acc': acc})
    return loss

  def configure_optimizers(self):
    optimizer = torch.optim.Adam(self.parameters(), lr=0.0001)
    return optimizer

# %%
# torch.save(model.state_dict(), '/content/drive/MyDrive/AmazonML/lightningBERTmini.bin')

model = AmazonModel()
model.load_state_dict(torch.load('/content/drive/MyDrive/AmazonML/lightningBERTsmalltpu.bin'))
# Out:
# Some weights of the model checkpoint at prajjwal1/bert-small were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# <All keys matched successfully>

# %%
test = pd.read_csv('/content/drive/MyDrive/AmazonML/input/dataset/test.csv', escapechar='\\', quoting=csv.QUOTE_NONE)
test.head()
# Out:
#    PRODUCT_ID  ...           BRAND
# 0           1  ...         Command
# 1           2  ...          O'Neal
# 2           3  ...  Boelter Brands
# 3           4  ...       Panasonic
# 4           5  ...            Zero
#
# [5 rows x 5 columns]

# %%
test.fillna('nan', inplace=True)
len(test)
# Out:
# 110775

# %%
test['TITLE'] = clean(test['TITLE'])
test['BULLET_POINTS'] = clean(test['BULLET_POINTS'])

# %%
class TestDataset(Dataset):
  def __init__(self, df, tokenizer):
    self.titles = df['TITLE'].values
    self.des = df['DESCRIPTION'].values
    self.bp = df['BULLET_POINTS'].values
    self.pids = df['PRODUCT_ID'].values
    self.tokenizer = tokenizer

  def __len__(self):
    return len(self.titles)

  def __getitem__(self, idx):
    title = str(self.titles[idx])
    bp = str(self.bp[idx])
    pid = self.pids[idx]

    inputs = self.tokenizer.encode_plus(
        title, bp,
        add_special_tokens=True,
        max_length = config.max_len,
        truncation = True,
        padding = True
    )

    ids = inputs['input_ids']
    token_type_ids = inputs['token_type_ids']
    mask = inputs['attention_mask']

    padding_len = config.max_len - len(ids)
    ids =  ids + ([0] * padding_len)
    token_type_ids = token_type_ids + ([0] * padding_len)
    mask = mask + ([0] * padding_len)

    return {'ids':torch.tensor(ids, dtype=torch.long),
            'mask':torch.tensor(mask, dtype=torch.long),
            'ttids':torch.tensor(token_type_ids, dtype=torch.long),
            'pid':torch.tensor(pid, dtype=torch.long)}

# %%
test_ds = TestDataset(test, tokenizer)

test_dl = DataLoader(test_ds,
                      batch_size=512,
                      num_workers=4,
                      pin_memory=True)

# %%
model.to('cuda')
model.eval()
with torch.no_grad():
  product_ids = []
  preds = []
  for batch in tqdm(test_dl, total=len(test_dl)):
    ids, mask, ttids, pids = batch['ids'], batch['mask'], batch['ttids'], batch['pid']
    ids = ids.to('cuda')
    mask = mask.to('cuda')
    ttids = ttids.to('cuda')
    product_ids += list(pids.numpy())
    preds += list(np.argmax(model(ids, mask, ttids).cpu().detach().numpy(), axis=1))
# Out:
#   0%|          | 0/217 [00:00<?, ?it/s]

# %%
# le = LabelEncoder()
# transformed = le.fit_transform(df['label3'])

# %%
# inverse = {}
# for i, j in zip(transformed, df['label3'].values):
#   inverse[i] = j

# %%
# Temp sub
sub = pd.DataFrame()
sub['PRODUCT_ID'] = product_ids
sub['BROWSE_NODE_ID'] = preds
sub['BROWSE_NODE_ID'] = sub['BROWSE_NODE_ID'].map(inverse)

# %%
sub.head()
# Out:
#    PRODUCT_ID  BROWSE_NODE_ID
# 0           1            1008
# 1           2            2516
# 2           3               1
# 3           4             112
# 4           5            5290

# %%
sub.to_csv('./submission.csv', index=False)
